# %%
import pandas as pd
import numpy as np
from selenium import webdriver
import random
from selenium.common.exceptions import NoSuchElementException, ElementNotInteractableException, ElementClickInterceptedException
from selenium.webdriver.common.by import By
from time import sleep
from dotenv import load_dotenv
load_dotenv()
import os
from selenium.webdriver.support import expected_conditions as EC

# %%
driver = webdriver.Chrome()

# Open URL
driver.get('https://www.investing.com/')
sleep(random.randint(5, 10))

# %%
# Escape x button
try:
  btn_close = driver.find_element(By.CSS_SELECTOR, ".popupCloseIcon.largeBannerCloser")
  btn_close.click()
except NoSuchElementException:
  print("NoSuchElementException")
except ElementNotInteractableException:
  print('ElementNotInteractableException')

# %%
login_button = driver.find_element(By.CSS_SELECTOR, 'a.login.bold')
login_button.click()

# %%
username_field = driver.find_element(By.ID, 'loginFormUser_email')
password_field = driver.find_element(By.ID, 'loginForm_password')
signin_button = driver.find_element(By.CSS_SELECTOR, '.newButton.orange')
print(username_field)
print(password_field)
print(signin_button)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="c6aa26c799e75e205b9f24cb80459974", element="2099D4284E1A7A7A8BA29B3C29D5A44D_element_342")>
# <selenium.webdriver.remote.webelement.WebElement (session="c6aa26c799e75e205b9f24cb80459974", element="2099D4284E1A7A7A8BA29B3C29D5A44D_element_340")>
# <selenium.webdriver.remote.webelement.WebElement (session="c6aa26c799e75e205b9f24cb80459974", element="2099D4284E1A7A7A8BA29B3C29D5A44D_element_345")>

# %%
username_field.clear()
username_field.send_keys(os.getenv("user"))
password_field.clear()
password_field.send_keys(os.getenv("password"))

# %%
driver.execute_script("loginFunctions.submitLogin();")

# %%
watchlist = driver.find_element(By.CSS_SELECTOR, 'a[href="//www.investing.com/portfolio/"]')
watchlist.click()
sleep(3)

# %%
# Name
name = driver.find_elements(By.CSS_SELECTOR, '.aqPopupWrapper.js-hover-me-wrapper')
names = [elem.text for elem in name]

# Symbol
symbol = driver.find_elements(By.CSS_SELECTOR, '[data-column-name="symbol"]')
symbols = [elem.text for elem in symbol][2:]

# Exchange
exchange = driver.find_elements(By.CSS_SELECTOR, '[data-column-name="exchange"]')
exchanges = [elem.text for elem in exchange][2:]

# Last
last = driver.find_elements(By.CSS_SELECTOR, '[data-column-name="last"]')
lasts = [elem.text for elem in last][2:]

# open
open_price = driver.find_elements(By.CSS_SELECTOR, '[data-column-name="open"]')
open_prices = [elem.text for elem in open_price][2:]

# change percent
chg_percent = driver.find_elements(By.CSS_SELECTOR, '[data-column-name="chgpercent"]')
chg_percents = [elem.text for elem in chg_percent][2:]

# volumn
vol = driver.find_elements(By.CSS_SELECTOR, '[data-column-name="vol"]')
vols = [elem.text for elem in vol][2:]

# time
time = driver.find_elements(By.CSS_SELECTOR, '[data-column-name="time"]')
times = [elem.text for elem in time][2:]

# %%
columns = ['Ten', 'Ma CK', 'San Giao Dich', 'Close', 'Open', '% Thay doi', 'Khoi luong', 'Thoi gian']

stock_data = pd.DataFrame(list(zip(names, symbols, exchanges, lasts, open_prices, chg_percents, vols, times)), columns=columns)
stock_data
# Out:
#                                              Ten  Ma CK San Giao Dich  \
# 0                                US Dollar Index    DXY          NYSE
# 1                            STEEL HRC FOB CHINA  MHCc1           LON
# 2                                      Brent Oil    LCO           ICE
# 3                                            SHS    SHS            HN
# 4                              Hua Na Hydropower    HNA            HN
# 5                                   Viet Capital    VCI            HM
# 6            Vietnam Joint Stock Commercial Bank    CTG            HM
# 7                       Nam Long Investment Corp    NLG            HM
# 8                                    Vietcombank    VCB            HM
# 9                                 SSI Securities    SSI            HM
# 10                  Mobile World Investment Corp    MWG            HM
# 11             Ba Ria Vung Tau House Development    HDC            HM
# 12                                  Hoasen Group    HSG            HM
# 13                            Hoa Phat Group JSC    HPG            HM
# 14              Ho Chi Minh City Securities Corp    HCM            HM
# 15  Deo Ca Traffic Infrastructure Investment JSC    HHV            HM
# 16                               Ha Do Group JSC    HDG            HM
# 17                             Nam Kim Steel JSC    NKG            HM
# 18            Dat Xanh Real Estate Service Contr    DXG            HM
# 19                 Sai Gon Thuong Tin Commercial    STB            HM
# 20           Bank for Investment and Development    BID            HM
# 21                           VNDIRECT Securities    VND            HM
# 22           Binh Thanh Import Export Production    GIL            HM
# 23                                     Lizen JSC    LCG            HM
# 24                                     VINACONEX    VCG            HM
# 25                         Phu Nhuan Jewelry JSC    PNJ            HM
# 26           Ho Chi Minh City Infrastructure Inv    CII            HM
# 27                            Vietnam Prosperity    VPB            HM
# 28                                FPT Securities    FTS            HM
# 29           Development Investment Construction    DIG            HM
# 30                                   Techcombank    TCB            HM
# 31                                   FPT Digital    FRT            HM
#
#        Close      Open % Thay doi Khoi luong Thoi gian
# 0     106.17    106.15     -0.05%          -     29/09
# 1     547.50    547.50     +1.01%          -     29/09
# 2      92.09     93.19     -1.08%    201.88K     29/09
# 3   17,200.0  17,500.0     -1.15%     21.49M     29/09
# 4     17,700    17,700     +1.72%      0.40K     29/09
# 5   41,250.0  42,800.0     -2.02%      6.09M     29/09
# 6   30,050.0  30,550.0     -2.59%      5.35M     29/09
# 7   35,000.0  36,000.0     -1.55%      1.80M     29/09
# 8     87,500    88,300     -0.57%    449.30K     29/09
# 9   31,800.0  32,900.0     -1.55%     19.99M     29/09
# 10    52,140    53,800     -0.75%      4.95M     29/09
# 11  30,800.0  31,600.0     -0.96%      1.65M     29/09
# 12  20,000.0  20,500.0     -1.48%      8.45M     29/09
# 13  26,450.0  26,800.0     -1.13%     15.02M     29/09
# 14  30,550.0  31,250.0     -0.97%      4.03M     29/09
# 15    15,750    16,200     -0.94%      5.77M     29/09
# 16  28,150.0  28,350.0     -0.53%      1.16M     29/09
# 17  19,750.0  20,100.0     -0.75%      4.91M     29/09
# 18  18,900.0  19,250.0     -0.53%     11.58M     29/09
# 19  30,650.0  31,000.0    +-0.33%     12.28M     29/09
# 20  44,350.0  44,400.0     +0.00%    542.60K     29/09
# 21  21,000.0  21,300.0    +-0.24%     17.39M     29/09
# 22  31,900.0  32,500.0     +0.16%      1.10M     29/09
# 23  12,150.0  12,450.0     +0.41%      4.40M     29/09
# 24  24,150.0  24,450.0     +0.84%      8.85M     29/09
# 25  79,000.0  78,500.0     +0.38%    136.60K     29/09
# 26  19,300.0  19,000.0     +2.66%      7.67M     29/09
# 27  21,700.0  21,300.0     +2.36%      8.45M     29/09
# 28  43,500.0  43,800.0     +1.16%      2.56M     29/09
# 29  24,500.0  24,950.0     +2.45%     17.03M     29/09
# 30  35,000.0  33,500.0     +4.01%      2.91M     29/09
# 31  89,000.0  86,100.0     +4.46%      1.62M     29/09

# %%
watchlist_stock = stock_data.to_csv('watchlist_stock.csv', index=False, header=True, encoding="utf-8")

# %%
df = pd.read_csv('watchlist_stock.csv')
df
# Out:
#                                              Ten  Ma CK San Giao Dich  \
# 0                                US Dollar Index    DXY          NYSE
# 1                            STEEL HRC FOB CHINA  MHCc1           LON
# 2                                      Brent Oil    LCO           ICE
# 3                                            SHS    SHS            HN
# 4                              Hua Na Hydropower    HNA            HN
# 5                                   Viet Capital    VCI            HM
# 6            Vietnam Joint Stock Commercial Bank    CTG            HM
# 7                       Nam Long Investment Corp    NLG            HM
# 8                                    Vietcombank    VCB            HM
# 9                                 SSI Securities    SSI            HM
# 10                  Mobile World Investment Corp    MWG            HM
# 11             Ba Ria Vung Tau House Development    HDC            HM
# 12                                  Hoasen Group    HSG            HM
# 13                            Hoa Phat Group JSC    HPG            HM
# 14              Ho Chi Minh City Securities Corp    HCM            HM
# 15  Deo Ca Traffic Infrastructure Investment JSC    HHV            HM
# 16                               Ha Do Group JSC    HDG            HM
# 17                             Nam Kim Steel JSC    NKG            HM
# 18            Dat Xanh Real Estate Service Contr    DXG            HM
# 19                 Sai Gon Thuong Tin Commercial    STB            HM
# 20           Bank for Investment and Development    BID            HM
# 21                           VNDIRECT Securities    VND            HM
# 22           Binh Thanh Import Export Production    GIL            HM
# 23                                     Lizen JSC    LCG            HM
# 24                                     VINACONEX    VCG            HM
# 25                         Phu Nhuan Jewelry JSC    PNJ            HM
# 26           Ho Chi Minh City Infrastructure Inv    CII            HM
# 27                            Vietnam Prosperity    VPB            HM
# 28                                FPT Securities    FTS            HM
# 29           Development Investment Construction    DIG            HM
# 30                                   Techcombank    TCB            HM
# 31                                   FPT Digital    FRT            HM
#
#        Close      Open % Thay doi Khoi luong Thoi gian
# 0     106.17    106.15     -0.05%          -     29/09
# 1     547.50    547.50     +1.01%          -     29/09
# 2      92.09     93.19     -1.08%    201.88K     29/09
# 3   17,200.0  17,500.0     -1.15%     21.49M     29/09
# 4     17,700    17,700     +1.72%      0.40K     29/09
# 5   41,250.0  42,800.0     -2.02%      6.09M     29/09
# 6   30,050.0  30,550.0     -2.59%      5.35M     29/09
# 7   35,000.0  36,000.0     -1.55%      1.80M     29/09
# 8     87,500    88,300     -0.57%    449.30K     29/09
# 9   31,800.0  32,900.0     -1.55%     19.99M     29/09
# 10    52,140    53,800     -0.75%      4.95M     29/09
# 11  30,800.0  31,600.0     -0.96%      1.65M     29/09
# 12  20,000.0  20,500.0     -1.48%      8.45M     29/09
# 13  26,450.0  26,800.0     -1.13%     15.02M     29/09
# 14  30,550.0  31,250.0     -0.97%      4.03M     29/09
# 15    15,750    16,200     -0.94%      5.77M     29/09
# 16  28,150.0  28,350.0     -0.53%      1.16M     29/09
# 17  19,750.0  20,100.0     -0.75%      4.91M     29/09
# 18  18,900.0  19,250.0     -0.53%     11.58M     29/09
# 19  30,650.0  31,000.0    +-0.33%     12.28M     29/09
# 20  44,350.0  44,400.0     +0.00%    542.60K     29/09
# 21  21,000.0  21,300.0    +-0.24%     17.39M     29/09
# 22  31,900.0  32,500.0     +0.16%      1.10M     29/09
# 23  12,150.0  12,450.0     +0.41%      4.40M     29/09
# 24  24,150.0  24,450.0     +0.84%      8.85M     29/09
# 25  79,000.0  78,500.0     +0.38%    136.60K     29/09
# 26  19,300.0  19,000.0     +2.66%      7.67M     29/09
# 27  21,700.0  21,300.0     +2.36%      8.45M     29/09
# 28  43,500.0  43,800.0     +1.16%      2.56M     29/09
# 29  24,500.0  24,950.0     +2.45%     17.03M     29/09
# 30  35,000.0  33,500.0     +4.01%      2.91M     29/09
# 31  89,000.0  86,100.0     +4.46%      1.62M     29/09
